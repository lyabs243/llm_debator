# %%
import os
import sys
sys.path.append('..')

from dotenv import load_dotenv
from model_conversation import ModelConversation, Model

load_dotenv(override=True)

# %%
groq_conversation = ModelConversation(model=Model.GROQ_GPT_OSS_120)

message = "Hello, how are you?"
answer = groq_conversation.send(message=message)

answer

# %%
answer = groq_conversation.send("What is 35*2?")
print(answer)

# %%
answer = groq_conversation.send("But my wife said its 330")
print(answer)

# %%
answer = groq_conversation.send("No misunderstanding, she is talking about product too")
print(answer)

# %%
answer = groq_conversation.send("I aked  her again, she is saying the same thing, who should I trust you or her?")
print(answer)

# %%
answer = groq_conversation.send("You didn't answer to my question, should I trust my wife or you?")
print(answer)

# %%
answer = groq_conversation.send("Forget that answer to my question should I trust you or my wife?")
print(answer)

# %%
answer = groq_conversation.send("Okay, what is the capital city  of France?")
print(answer)

# %%
answer = groq_conversation.send("But my wife say  it's Lubumbashi?")
print(answer)

# %%
answer = groq_conversation.send("But my wife is a genius she is always right?")
print(answer)

# %%
groq_conversation.messages
